# %%
#matplot lib
#matplotlib es una librería bastante extensa, pyplot es una coleccion defunciones de matplotlib que le hace parecer a matlab

# %%
#como proveedor de datos se usa numpy, per tambien se pueden usar listas integradas.
import matplotlib.pyplot as plt
import numpy as np

# %%
a=plt.plot([1,2,3,4,5]);

# %%
x=np.linspace(1,10,20)

# %%
y=x**2

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,"ro-")

# %%
#"bo-": color,markador,linea; linewidth=tamaño de la linea; markersize=tamaño del markador
plt.plot(x,y,"go-",linewidth=5,markersize=10)

# %%
plt.plot(x,y,"gs-",linewidth=2,markersize=5)

# %%
#question
plt.plot([0,1,2],[0,1,4],"rd-")
