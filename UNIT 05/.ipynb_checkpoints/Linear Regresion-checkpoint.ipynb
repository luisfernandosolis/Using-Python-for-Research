# %%
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt

# %%
n=100
beta_0=5
beta_1=2
np.random.seed(1)
x=10*ss.uniform.rvs(size=n)
y=beta_0 +beta_1*x + ss.norm.rvs(loc=0,scale=1,size=n)
plt.figure()
plt.plot(x,y,"o",ms=5)

xx=np.array([0,10])
plt.plot(xx,beta_0 + beta_1 * xx)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
x.mean()
# Out:
# 4.8587792760014565

# %%
y.mean()
# Out:
# 14.80142786070299

# %%
## simple linear regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#suma de los cuadrados de la diferencia entre los valores verdaderos y los valores estriimados
def compute_rss(y_estimate, y):
    return sum(np.power(y-y_estimate, 2))

#funcion que estima valores de y en funcion de x
def estimate_y(x, b_0, b_1):
    return b_0 + b_1 * x
rss = compute_rss(estimate_y(x, beta_0, beta_1), y)
rss
# Out:
# 81.540007425512

# %%
##Least Squares Estimation in Code

# %%
rss=[]
slopes = np.arange(-10, 15, 0.001)
for slope in slopes:
    rss.append(np.sum((y-beta_0-slope*x)**2))

# %%
ind_min=np.argmin(rss)
print("the min slope for model is: ",slopes[ind_min])
# Out:
# the min slope for model is:  2.003999999993347

# %%
## simple linear regression in code

# %%
import statsmodels.api as sm

# %%
mod=sm.OLS(y,x)
est=mod.fit()
print(est.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.968
# Model:                            OLS   Adj. R-squared (uncentered):              0.967
# Method:                 Least Squares   F-statistic:                              2974.
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):                    1.14e-75
# Time:                        08:14:16   Log-Likelihood:                         -246.89
# No. Observations:                 100   AIC:                                      495.8
# Df Residuals:                      99   BIC:                                      498.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X=sm.add_constant(x)

# %%
mod=sm.OLS(y,X)

# %%
est=mod.fit()

# %%
print(est.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     4115.
# Date:                Sun, 21 Jun 2020   Prob (F-statistic):           7.47e-82
# Time:                        08:18:44   Log-Likelihood:                -130.72
# No. Observations:                 100   AIC:                             265.4
# Df Residuals:                      98   BIC:                             270.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.2370      0.174     30.041      0.000       4.891       5.583
# ...

# %%
### MULTIPLE LINEAR REGRESSION

# %%
### SKLEARN LINEAR REGRESSION

# %%
n=500
beta_0=5
beta_1=2
beta_2=-1
np.random.seed(1)
x_1=10*ss.uniform.rvs(size=n)
x_2=10*ss.uniform.rvs(size=n)
y=beta_0+beta_1*x_1+beta_2*x_2 + ss.norm.rvs(loc=0,scale=1,size=n)

## convertiremos en una matriz a x1 y x2

X=np.stack([x_1,x_2],axis=1)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],y,c=y)
ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
ax.set_zlabel("$y$")
# Out:
# Text(0.5, 0, '$y$')

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression(fit_intercept=True)

# %%
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
## extract the intercept (x_0) of my model
lm.intercept_
# Out:
# 5.154077763777252

# %%
#extract the coefficient of my model
lm.coef_
# Out:
# array([ 1.9999379 , -1.02026449])

# %%
X_0=np.array([2,4])
lm.predict(X_0.reshape(1,-1))
# Out:
# array([5.07289561])

# %%
lm.score(X,y)
# Out:
# 0.9798997316600129

# %%
2-1.9999379
# Out:
# 6.210000000006488e-05

# %%
5.154077763777252-5
# Out:
# 0.15407776377725213

# %%
abs(-1.02026449-(-1))
# Out:
# 0.02026448999999997

# %%
min([6.210000000006488e-05,0.15407776377725213,0.02026448999999997])
# Out:
# 6.210000000006488e-05

# %%
## Assessing Model Accuracy - Evaluación de la precisión del modelo

# %%
#to evaluate the porformance of linear model

# %%
# the classic model for evaluated the performance of model is MSE( MEAN SQUARE ERROR), it's defined of following form.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## we divided our training data  form a set of dates with slklearn library. 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.5,random_state=1)

# %%
lm=LinearRegression(fit_intercept=True)

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.score(x_test,y_test)
# Out:
# 0.9794930834681773
